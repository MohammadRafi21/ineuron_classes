# %% [markdown]
# # Sets

# %% [markdown]
# sets are unordered collection of data items. They store multiple items in a single variable. Set itmes are seperated by commas and enclosed with ---->"{}". Sets are unchangeable what means it is immutable(you can't change the items once created). Sets do not contain any duplicate value.

# %%
info = {'rafi',19,False,5.9,10}

# %%
type(info)
# Out:
# set

# %%
 info
# Out:
# {10, 19, 5.9, False, 'rafi'}

# %%
info1 = {'rafi','rafi','rafi','rafi','bappy','kumar','sunny'}

# %%
info1
# Out:
# {'bappy', 'kumar', 'rafi', 'sunny'}

# %%
info1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 info1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
info1 = list(info1)
info1
# Out:
# ['sunny', 'kumar', 'bappy', 'rafi']

# %%
info1[0]
# Out:
# 'sunny'

# %%
info1 = {'rafi','rafi','rafi','rafi','bappy','kumar','sunny'}



for data in info1:
    print(data)
# Out:
# sunny
# kumar
# bappy
# rafi

# %% [markdown]
# #### you cannot add or delete or change anything in the set
# #### to change anything in the set you have to convert it into list and then change the data

# %%
name = {}

# %%
type(name)
# Out:
# dict

# %%
name1 = set() # empty set

# %%
type(name1)
# Out:
# set

# %%
s = {''}

# %%
s = {'a','a',1,0.2,True,False}

# %%
s
# Out:
# {0.2, 1, False, 'a'}

# %%
s1 = {True}

# %%
s1
# Out:
# {True}

# %%
s2 = {1,True} # 1 & True have same neumerical value that is why it is printing 1 only


s2
# Out:
# {1}

# %%
s= {1.1,True}

# %%
s
# Out:
# {True, 1.1}

# %% [markdown]
# ### List =====> mutable, can change add or delete items from the data
#
# ### Tuple =====> immutable, cannot change or add anything need Type casting (change it to list)
#
# ### dict ======> mutable, has some inbuilt method
#
# ### sets ======> immutable, cannot change or add anything need Type casting (change it to list)
