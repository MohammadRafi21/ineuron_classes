# %% [markdown]
# # String
#
#
# string is immutable data type

# %%
string = 'Rafi'

# %%
string[0]
# Out:
# 'R'

# %%
type(string[0])
# Out:
# str

# %%
name = 'bappy'

# %%
type(name)
# Out:
# str

# %%
name[1]
# Out:
# 'a'

# %% [markdown]
# ### upper() & lower()

# %%
str1 = 'Rafi'

# %%
str1.upper()
# Out:
# 'RAFI'

# %%
str2 = 'RaFI'

# %%
str2.upper()
# Out:
# 'RAFI'

# %%
str2.lower()
# Out:
# 'rafi'

# %%
str3 = 'Pyhton is very powerful programming language'

# %%
str3.upper()
# Out:
# 'PYHTON IS VERY POWERFUL PROGRAMMING LANGUAGE'

# %%
str3.lower()
# Out:
# 'pyhton is very powerful programming language'

# %%
str3
# Out:
# 'Pyhton is very powerful programming language'

# %%
str5 = 'Python'

# %%
print(str5)
# Out:
# Python

# %%
str5 = str5.upper() 

print(str5)
# Out:
# PYTHON

# %%
str6 = '12345'

# %%
str6[0:2]
# Out:
# '12'

# %%
str7 = 'Data Science'

# %%
first = str7[0:5].lower()
first
# Out:
# 'data '

# %%
last = str7[5:].upper()
last
# Out:
# 'SCIENCE'

# %%
first + last
# Out:
# 'data SCIENCE'

# %% [markdown]
# ## strip()
#
# it is removing the extra space

# %%
str8 = 'My name is Bappy              '

# %%
str8
# Out:
# 'My name is Bappy              '

# %%
str8.strip() ## it is striping the extra spaces form the string
# Out:
# 'My name is Bappy'

# %% [markdown]
# ## rstrip()
#
# it is removing the symbol or character in the end of the string

# %%
str8 = 'My name is Rafi!!!!!!!!!!!!!!'

# %%
str8.rstrip('!')
# Out:
# 'My name is Rafi'

# %%
str9 = '!!!!!!!!!!!!!!My name is Rafi!!!!!!!!!!!!!!'

# %%
str9.rstrip('!')
# Out:
# '!!!!!!!!!!!!!!My name is Rafi'

# %%
str10 = "My name is Rafi111111111"

# %%
str10.rstrip('1')
# Out:
# 'My name is Rafi'

# %% [markdown]
# ## replace()

# %%
str11 = 'Silver Spoon'

# %%
str11.replace('Sp','M')
# Out:
# 'Silver Moon'

# %%
str4 = 'My name is Rafi & I am a Data Scientist'

# %%
str4.replace('Rafi','G M')
# Out:
# 'My name is G M & I am a Data Scientist'

# %%
str4 = 'My name is Rafi & Rafi am a Data Scientist'

# %%
str4.replace('Rafi','G M')
# Out:
# 'My name is G M & G M am a Data Scientist'

# %%
str9 = '!!!!!!!!!!!!!!My name is Rafi!!!!!!!!!!!!!!'

# %%
str9 = str9.rstrip('!')

# %%
str9 = str9.replace('!',' ')

# %%
str9
# Out:
# '              My name is Rafi'

# %%
str9 = str9.strip()

# %%
str9
# Out:
# 'My name is Rafi'

# %%
sen1 = '@@@ My name is Rafi. I am a AI developer ######'

# %%
sen1 = sen1.replace('#','')
sen1 = sen1.replace('@','')
sen1 = sen1.strip()
print(sen1)
# Out:
# My name is Rafi. I am a AI developer

# %%
sen1 = '@@@ My name is Rafi. I am a AI developer ######'

# %%
sen1 = sen1.replace('#','').replace('@','').strip()

print(sen1)
# Out:
# My name is Rafi. I am a AI developer

# %% [markdown]
# ## split()
#
#
#   Transform the string into list dividing in the space by default but if you want to split the string in a specific position you have to mention that with in the method

# %%
str5 = 'Silver Spoon'

# %%
str5
# Out:
# 'Silver Spoon'

# %%
str5 = str5.split() # spliting in the space by default

# %%
str5
# Out:
# ['Silver', 'Spoon']

# %%
type(str5)
# Out:
# list

# %%
str4 = 'Silver,Spoon'

# %%
str4 = str4.split(',') # ', is mentioned in the method'

str4
# Out:
# ['Silver', 'Spoon']

# %%
student_list = 'Rafi Bappy Saiful Iqbal'

# %%
student_list.split()
# Out:
# ['Rafi', 'Bappy', 'Saiful', 'Iqbal']

# %%
student_list = 'Rafi@Bappy@Saiful@Iqbal'

# %%
student_list.split('@')
# Out:
# ['Rafi', 'Bappy', 'Saiful', 'Iqbal']

# %% [markdown]
# ## capitalized()

# %%
sen2 = "data science is Future"

# %%
sen2
# Out:
# 'data science is Future'

# %%
sen2.capitalize()
# Out:
# 'Data science is future'

# %% [markdown]
# ## center()

# %%
str1 = 'Welcome to the jungle'

# %%
print(str1)
# Out:
# Welcome to the jungle

# %%
str1.center(50)
# Out:
# '              Welcome to the jungle               '

# %%
str1.center(100)
# Out:
# '                                       Welcome to the jungle                                        '

# %%
str1.center(100,"-")
# Out:
# '---------------------------------------Welcome to the jungle----------------------------------------'

# %%
temp = str1.center(100,"-")

len(temp)
# Out:
# 100

# %% [markdown]
# ## count()
#
# to count the character within the string

# %%
str9 = 'aaaaaahhhhhhbbbbbbbekkkkkkkkppppp'

# %%
str9.count('a')
# Out:
# 6

# %%
str2 = 'Bond, James Bond is my name'

# %%
str2.count('Bond')
# Out:
# 2

# %% [markdown]
# ## find()
# it will give you the index of that character or the string that you are looking for within the string

# %%
str12 = 'My name is Rafi'

# %%
str12.find('is')
# Out:
# 8

# %%
str13 = 'He is Dan. He is an honest man'


print(str13.find('Daniel')) ## If the find method could not find anyone it will return -1
# Out:
# -1

# %% [markdown]
# ## index()
#
# it will give me the index of the string

# %%
str13 = 'He is Dan. He is an honest man'

# %%
str13.index('Dan')
# Out:
# 6

# %%
str13[6:9]
# Out:
# 'Dan'

# %%
str13.index('Daniel')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 str13.index('Daniel')
#
# ValueError: substring not found

# %% [markdown]
# ## islower()
#
# it will check if the string is lower or not

# %%
sen = 'how are u'

# %%
sen.islower()
# Out:
# True

# %% [markdown]
# ## isupper()
#
# same like islower()

# %%
sen1 = 'HOW ARE U'

# %%
sen1.isupper()
# Out:
# True

# %% [markdown]
# ## startswith()

# %%
sen2 = 'Python is a interpreted language'

# %%
sen2.startswith('python')
# Out:
# False

# %%
sen2.startswith('Python')
# Out:
# True
