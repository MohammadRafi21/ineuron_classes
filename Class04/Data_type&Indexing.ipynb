# %% [markdown]
# # Boolean

# %%
bool1 = True #this true us case sensitive

# %%
bool2 = False

# %%
a = 4
b = 9

# %%
a > b
# Out:
# False

# %%
b1 = True
b2 = True  # Internally Python store the value of "True" is 1

# %%
print(b1 + b2)
# Out:
# 2

# %%
b3 = True
b4 = False # Internally Python store the value of "True" is 1 and the value of "False" is 0

# %%
print(b3 + b4)
# Out:
# 1

# %%
-1 == True
# Out:
# False

# %%
1 == True # Value of True is 1
# Out:
# True

# %%
0 == False # Value of False is 0
# Out:
# True

# %% [markdown]
# # Strings

# %%
str1 = "Rafi"

# %%
type(str1)
# Out:
# str

# %%
str2 = "m"
type(str2)
# Out:
# str

# %%
# we don't have any "chr" datatype in the python

# %% [markdown]
#  ##### String is a collection of character in python

# %%
str3 = 'Rafi'
str4 = "john2"

# %%
print(str3)
# Out:
# Rafi

# %%
str3
# Out:
# 'Rafi'

# %%
print(str4)
# Out:
# john2

# %%
str4
# Out:
# 'john2'

# %%
ord('A')
# Out:
# 65

# %%
ord('@')
# Out:
# 64

# %%
ord('ma')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 ord('ma')
#
# TypeError: ord() expected a character, but string of length 2 found

# %%
ord('%')
# Out:
# 37

# %%
ord('a')
# Out:
# 97

# %% [markdown]
# ## Python solve the question given in the class

# %%
mystr1 = "Mayank's Code"
print(mystr1)
# Out:
# Mayank's Code

# %%
mystr2 = 'Let us "Code" today'
print(mystr2)
# Out:
# Let us "Code" today

# %%
mystr3 = '''Let's "Code"'''
print(mystr3)
# Out:
# Let's "Code"

# %% [markdown]
# # Multi Line Sting

# %%
MultiLineString = "line 1
line 2
line 3 "
# Out:
#   Cell In[48], line 1
#     MultiLineString = "line 1
#                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
MultiLineString = 'line 1
line 2
line 3 '
# Out:
#   Cell In[49], line 1
#     MultiLineString = 'line 1
#                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# ### Using the triple quote

# %%
multiLineString = '''line1
line2
line3'''

# %%
print(multiLineString)
# Out:
# line1
# line2
# line3

# %%
multiLineString
# Out:
# 'line1\nline2\nline3'

# %%
strAns5 = 'Let\'s "Code"'
print(strAns5)
# Out:
# Let's "Code"

# %%
strAns6 = "Let\"s 'Code'"
print(strAns6)
# Out:
# Let"s 'Code'

# %%
strAns7 ='let \abc' # the "\" sign helps python to ignore the next character in the string 
print(strAns7)
# Out:
# let bc

# %% [markdown]
# # Indexing

# %%
str1 = 'python'

# %% [markdown]
# #### How can we access Single char form our string?

# %%
mystr = 'PYTHON'

# %%
mystr[0]
# Out:
# 'P'

# %%
mystr2 = "HELLO WORLD"

# %%
mystr2[5]
# Out:
# ' '

# %%
mystr[11]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 mystr[11]
#
# IndexError: string index out of range

# %% [markdown]
# # Negative Indexing

# %%
mystr
# Out:
# 'PYTHON'

# %%
mystr[-1]
# Out:
# 'N'

# %%
mystr[-5]
# Out:
# 'Y'

# %%
mystr[-4]
# Out:
# 'T'

# %%
mystr[-4] == mystr[2]
# Out:
# True

# %%
mystr[len(mystr)-1] #in this code this will compiler will take a long time to aceess the last character of the string
# Out:
# 'N'

# %%
mystr[-1] #because of the special property of the python we can access the last char faster
# Out:
# 'N'

# %%
mystr[len(mystr)-1] == mystr[-1]
# Out:
# True

# %%
mystr2 = 'jkblajfjkhffjksnhfjhslkjfhslkjhflskdjhflkjsdhbvjehbgfg'

# %%
len(mystr2)
# Out:
# 54

# %%
mystr2[int(len(mystr2)/2)]
# Out:
# 'l'

# %%
mystr2[-1]
# Out:
# 'g'

# %% [markdown]
# # Range of Index

# %% [markdown]
# #### For Positive(+) indexing 0 < ..... < len-1
# #### For Negative(-) indexing -len < ..... < -1
# #### Any number which is grater than (len-1) or smaller than (-len) will give "OUT OF INDEX" error in the code

# %%
mystr[5]
# Out:
# 'N'

# %%
mystr[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 mystr[6]
#
# IndexError: string index out of range

# %%
mystr[-6]
# Out:
# 'P'

# %%
mystr[-7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 mystr[-7]
#
# IndexError: string index out of range

# %%
print(mystr[-4])

print(mystr[-4+len(mystr)])

mystr[-4] == mystr[-4+len(mystr)] #Converting  the negative index to positive
# Out:
# T
# T
# True

# %% [markdown]
# # Type Conversiton

# %% [markdown]
# #### Process of converting one type of data to another type is called type conversion

# %%
'5'+'5'
# Out:
# '55'

# %%
print(True + True)
# Out:
# 2

# %%
mystrnum= '52'

# %%
mystrnum + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 mystrnum + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
int(mystrnum) + 5
# Out:
# 57

# %%
ord('a')
# Out:
# 97

# %%
chr(97)
# Out:
# 'a'
