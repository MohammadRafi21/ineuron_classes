# %% [markdown]
# ## Data Type

# %% [markdown]
# Data type = type of data or identity of data present inside your variable

# %%
int a= 5 #python is dynamically typed
# Out:
#   Cell In[1], line 1
#     int a= 5 #python is dynamically typed
#         ^
# SyntaxError: invalid syntax

# %%
b=5

# %%
type(b)
# Out:
# int

# %%
a= "rafi"

# %%
type(a)
# Out:
# str

# %%
c=5.676

# %%
type(c)
# Out:
# float

# %% [markdown]
# we don't have any chr type in python

# %% [markdown]
# # Dynamic property of data

# %%
a= 5

# %%
type (a)
# Out:
# int

# %%
a= "rafi"

# %%
type(a)
# Out:
# str

# %% [markdown]
# in C++ and Java there is no dynamic property you have to predefine what is the data will be in that specific variable

# %% [markdown]
# # Size of the data type is also dynamic

# %%
m= 432

# %%
import sys

print(sys.getsizeof(m))
# Out:
# 28

# %%
m= 27978968976897

# %%
print(sys.getsizeof(m))
# Out:
# 32

# %%
m="rafi"

# %%
print(sys.getsizeof(m))
# Out:
# 53

# %% [markdown]
# ##### so here we can see the size is changing with the variable

# %%
from sys import getsizeof

t= "kja39u5"

# %%
getsizeof(t)
# Out:
# 56

# %% [markdown]
# ## Data types are Unbounded

# %%
a = 126498276498763897463987

# %%
a
# Out:
# 126498276498763897463987

# %%
getsizeof(a)
# Out:
# 36

# %% [markdown]
# # Numeric Data type

# %%
a = 374636

# %%
type(a)
# Out:
# int

# %%
b = 1e3

# %%
type(b)
# Out:
# float

# %%
b
# Out:
# 1000.0

# %%
c = 2e5

# %%
c
# Out:
# 200000.0

# %%
getsizeof(a)
# Out:
# 28

# %%
getsizeof(b)
# Out:
# 24

# %% [markdown]
# ## Float

# %%
fl= 4.56

# %%
type(fl)
# Out:
# float

# %% [markdown]
# ## Complex number

# %%
com1 = 3+2j

# %%
type(com1)
# Out:
# complex

# %%
getsizeof(com1)
# Out:
# 32
