# %%
2*3
# Out:
# 6

# %% [markdown]
# * the following one represents the 2 to the power 3

# %%
2**3
# Out:
# 8

# %% [markdown]
# ## Runtime Error

# %% [markdown]
#   ###### These are the error which we get during running of our program. As soon as python Interpretor faces this it stop our program execution

# %%
num = 50
den = 100

# %%
print(num /den)
# Out:
# 0.5

# %%
num =100
# Out:
#  25
# 4.0

# %%
den = int(input())
# Out:
#  0

# %%
print (num/den)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print (num/den)
#
# ZeroDivisionError: division by zero

# %%
start = -2
end = 2
while start<end:
    print(end/start)
    start=start+1
# Out:
# -1.0
# -2.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 end = 2
#       3 while start<end:
# ----> 4     print(end/start)
#       5     start=start+1
#
# ZeroDivisionError: division by zero

# %% [markdown]
# *** handeling the run time error

# %%
start = -2
end = 2
while start<end:
    if start == 0:
        start = start+1
        print("denominator is 0, moving to the next one")
        continue 
    print(end/start)
    start=start+1
# Out:
# -1.0
# -2.0
# denominator is 0, moving to the next one
# 2.0

# %% [markdown]
# Continue statement goes right back to the start of the loop
#
# and break statement goes out of the loop

# %% [markdown]
# ## Runtime error (Exceptions)
# ## exception handeling

# %%
num = int(input())
# Out:
#  rafi
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 num = int(input())
#
# ValueError: invalid literal for int() with base 10: 'rafi'

# %% [markdown]
# ## Fuction defined inside the Modules

# %%
 abs(-5)
# Out:
# 5

# %%
print("Hello")
# Out:
# Hello

# %%
sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math

# %%
sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
import math as m

# %%
m.sqrt(49)
# Out:
# 7.0

# %%
from math import sqrt as sq

# %%
sq(100)
# Out:
# 10.0

# %%
import numpy as np

# %% [markdown]
# Numpy is used for workin in the arrays of the python it is regarded as numerical python NumPy arrays are stored at one continuous place in memory unlike lists, so processes can access and manipulate them very efficiently.

# %%
import pandas as pd

# %% [markdown]
# Pandas is a Python library used for working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data.

# %%
import scipy as sc

# %% [markdown]
# SciPy is a scientific computation library that uses NumPy underneath. SciPy stands for Scientific Python.
# It provides more utility functions for optimization, stats and signal processing.
# for example sin(x) and cos(x)

# %% [markdown]
# ## Identifiers

# %%
a=5
b=5

# %%
a0=10

# %%
a0
# Out:
# 10

# %%
0a=20
# Out:
#   Cell In[4], line 1
#     0a=20
#     ^
# SyntaxError: invalid decimal literal

# %%
a@=50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a@=50
#
# TypeError: unsupported operand type(s) for @=: 'int' and 'int'

# %%
a_=50

# %%
_a=5

# %%
_a
# Out:
# 5

# %%
A=55

# %%
A
# Out:
# 55

# %%
0A = 56
# Out:
#   Cell In[12], line 1
#     0A = 56
#     ^
# SyntaxError: invalid decimal literal

# %%
_ = 65

# %%
_
# Out:
# 65

# %%
a = 6
b=7

# %%
def _(a,b):
    print(a+b)

# %%
_(5,7)
# Out:
# 12

# %%
def _sum(a,b):
    print(a+b)

# %%
_sum(78,7)
# Out:
# 85

# %%
import keyword
list= keyword.kwlist
print(list)
print(len(list))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35
