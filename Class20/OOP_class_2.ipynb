# %% [markdown]
# ## we cannot define multuple constructor in python, the latest one overrides the old one

# %%
class student:

  def __init__(self):
    self.__math = 0
    self.science = 0


  def __init__(self, math, science):
    self.math = math
    self.science = science

# %%
s1 = student()
s2 = student(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 s1 = student()
#       2 s2 = student(10,20)
#
# TypeError: student.__init__() missing 2 required positional arguments: 'math' and 'science'

# %% [markdown]
# ## in the above code the latest "__init__" constructor is overriding the previous "__init__" constructor

# %%
s2 = student(10,20) # now it is working

# %% [markdown]
# # Fraction Class

# %% [markdown]
#  ## Question : we have to define a class fraction which support all the operation of fraction and give user the chance to define fraction

# %%
5/8
# Out:
# 0.625

# %%
class Fraction:
  def __init__(self, num = 1, den = 1):

      self.num = num
      self.den = den
    

      if(den == 0):
        print("Denominator cannot be 0")
        self.num = num
        self.den = 1

  def __str__(self):
     return "{}/{}".format(self.num,self.den)
  
  def __add__(self,fraction2):
     self.num = self.num*fraction2.den + self.den*fraction2.num
     self.den = self.den * fraction2.den
     return "{}/{}".format(self.num,self.den)

# %%
f1  =  Fraction(3,5)
f2 = Fraction(4,5)

# %%
print(f1)
print(f2)
# Out:
# 3/5
# 4/5

# %%
print(f1.num)
# Out:
# 3

# %%
print(f2.num)
# Out:
# 4

# %%
f1 + f2
# Out:
# '35/25'

# %%
5 + 5
# Out:
# 10

# %%
[1,2] + [3,4]
# Out:
# [1, 2, 3, 4]

# %%
{1,2} + {2,3}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 {1,2} + {2,3}
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
f1 + f2
# Out:
# '35/25'

# %% [markdown]
# __https://rszalski.github.io/magicmethods/__ go to this link to see what are the magic fuction are

# %%
class Fraction:
    def __init__(self, num = 1, den = 1):
      
      self.num = num # instance variable
      self.den = den
      
      if(den == 0):
          print("Denominator cannot be 0")
          self.num = num
          self.den = 1
          
    def __str__(self):
        return "{}/{}".format(self.num,self.den)
  
    def __add__(self,fraction2):
       self.num = self.num*fraction2.den + self.den*fraction2.num
       self.den = self.den * fraction2.den
       ans = Fraction(self.num,self.den)
       ans.simplify()
       return ans
       #return "{}/{}".format(self.num,self.den)

    def myaddFuction(self,fraction2):
       self.num = self.num*fraction2.den + self.den*fraction2.num
       self.den = self.den * fraction2.den
       ans = Fraction(self.num,self.den)
       ans.simplify()
       return ans
       
    def __sub__(self, fraction2):
       self.num = self.num*fraction2.den - self.den*fraction2.num
       self.den = self.den * fraction2.den
       ans = Fraction(self.num,self.den)
       ans.simplify()
       return ans
       #return "{}/{}".format(self.num,self.den)
    def __mul__(self, fraction2):
       self.num = self.num*fraction2.num
       self.den = self.den * fraction2.den
       ans = Fraction(self.num,self.den)
       ans.simplify()
       return ans
       #return "{}/{}".format(self.num,self.den)
    def __truediv__(self, fraction2):
       self.num = self.num*fraction2.den
       self.den = self.den * fraction2.num
       ans = Fraction(self.num,self.den)
       ans.simplify()
       return ans
       #return "{}/{}".format(self.num,self.den)

   #  def __pow__(firstOperand, second_operand):
   #     self.num = self.num
   #     return "{}/{}".format(self.num,self.den)
    
    def simplify(self):
       
        ## get the GCD of numerator and denominator and return the ans after dividing by it
       ## make sure that all operation above return the ans after simplifying

       divisor = 2
       factors1 = self.prime_factor(self.num,divisor)
       factors2 = self.prime_factor(self.den,divisor)
       factors1.sort()
       factors2.sort()
       gcd = self.common_gcd(factors1,factors2)

       self.num = int(self.num/gcd)
       self.den = int(self.den/gcd)

       

   
      
    def prime_factor(self, n, divisor):
       
       l = []

       while n !=1:
         if n % divisor == 0:
            l.append(divisor)
            n = int(n/divisor)
         else:
            divisor +=1
            
       return l
    def common_gcd(self,l1,l2):
       i = 0
       j = 0
       gcd_c = 1
       while i<len(l1) and j<len(l2):
          if (l1[i] == l2[j]):
             gcd_c *= l1[i]
             i += 1
             j += 1
          elif (l1[i] > l2 [j]):
             j +=1
          else:
             i +=1
       return gcd_c

# %%
f1  =  Fraction(3,5) # changes of our operation we are storig it in self or f1
f2 = Fraction(4,5)

# %%
print(f1)
# Out:
# 3/5

# %%
print(f2)
# Out:
# 4/5

# %%
f3 = f1/f2

# %%
print(f3)
# Out:
# 3/4

# %%
print(f1)
# Out:
# 35/25

# %%
f1-f2

# %%
f1*f2

# %%
f1  =  Fraction(3,5) # changes of our operation we are storig it in self or f1
f2 = Fraction(4,5)

# %%
f1/f2
# Out:
# '15/20'

# %%
#f1 = Fraction(45,90)

# %%
#f1.simplify()
# Out:
# 1/2

# %%
f3 = Fraction(2,10)

# %%
print(f3)
# Out:
# 2/10

# %%
f1  =  Fraction(3,5) # changes of our operation we are storig it in self or f1
f2 = Fraction(4,5)

# %%
print(f1.myaddFuction(f2))
# Out:
# 7/5

# %%
class ATM:
    def __init__(self):
        self.pin = 4156456
        self.balance = 154651
        self.name = "Audrey"

# %%
cust1 = ATM()

# %%
cust1.pin = 789

# %%
cust1.pin
# Out:
# 789

# %% [markdown]
# this is a problem anyone can go in the programme and change the pin and balance and name

# %%
# national ID card

# %%
class Person:
    def __init__(self, NcardNo, name, mobile):
        self.Ncard_no = NcardNo # instance variable 
        self.name = name # instance variable 
        self.mobile = mobile # instance variable

# %%
person1 = Person("4154654", "Rafi", 1654654)
person2 = Person("3565", "Alexa", 5465456)

# %%
person1.Ncard_no
# Out:
# '4154654'

# %%
person2.Ncard_no
# Out:
# '3565'

# %% [markdown]
# ## Access Modifier in python
#
# it is not a good practice to keep our variables and instance variable accessible to everyone

# %%
person2.Ncard_no
# Out:
# '3565'

# %%
"BAN" + person2.Ncard_no
# Out:
# 'BAN3565'

# %%
person2.Ncard_no = 123

# %%
"BAN" + person2.Ncard_no
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 "BAN" + person2.Ncard_no
#
# TypeError: can only concatenate str (not "int") to str

# %%
class Person:
    def __init__(self, NID, name, mobile):
        self.__NID = NID # instance variable 
        self.name = name # instance variable 
        self.mobile = mobile # instance variable
    def getNIDforUN(self):
        return "BD" + self.__NID

# %%
person1 = Person("1234","Rafi","4654654")

# %%
person1.getNIDforUN()
# Out:
# 'BD1234'

# %%
# person1. # we are not seeing NID now

# %%
person1.__NID = 13456

# %%
person1.getNIDforUN()
# Out:
# 'BD1234'

# %%
class Mentor:

    def __init__(self, name, number):
        self.name = name
        #self.number = number
        self.__number = number # this "__" makes it private

    def __str__(self):
        print(self.name)
        print(self.__number)
        return ""

# %%
mentor1 = Mentor("rafi","467465")

# %%
print(mentor1)
# Out:
# rafi
# 467465

# %%
print(mentor1.name) # can access the name because it is public
# Out:
# rafi

# %%
print(mentor1.__number) # cannot access the number because it is private
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[204], line 1
# ----> 1 print(mentor1.__number)
#
# AttributeError: 'Mentor' object has no attribute '__number'

# %% [markdown]
# __Private members are instances variable which can only be accessed inside the class__

# %%
print(mentor1)
# Out:
# rafi
# 467465

# %%
mentor1.__number = 99989 # cannot get any access to the actual Mentor class
mentor1.__number # this is outside the class and it is public and we won't be using it
# Out:
# 99989

# %%
class Mentor:

    def __init__(self, name, number,NID):
        self.name = name
        #self.number = number
        self.__number = number # this "__" makes it private
        self.__NID = NID

    def __str__(self):
        print(self.name)
        print(self.__number)
        return ""
    def get_Mobile(self):  #getter (getting the private instance number)
        print(self.__number)
        return self.__number
    def set_Mobile(self, newNumber, password): #setter (setting the private instance number)
        if (password=="0123"):
            self.__number = newNumber
    def get_NID(self):  #getter (getting the private instance NID)
        print("*******" + self.__NID[-1])
        #return self.__NID
    def set_NID(self, newNID): #setter (setting the private instance NID)
        if(type(newNID) == str):
            self.__NID = newNID
        else:
            print("Please provide a string NID")
    def getNIDforUN(self):
        return "BD" + self.__NID

# %% [markdown]
# __for accessing private instaces we have to have getter and setter method__

# %%
mentor1 = Mentor("Rafi","0424164","648947651")

# %%
mentor1.get_NID()
# Out:
# *******1

# %%
mentor1.set_Mobile(46546) # only in this way you can change the private variable instance

# %%
mentor1.get_Mobile()
# Out:
# 46546
# 46546

# %% [markdown]
# __Just showing that we can set security of our own using getter and setter so that no one can access it__

# %%
mentor1.set_NID(1256456)
# Out:
# Please provide a string NID

# %%
mentor1.getNIDforUN()
# Out:
# 'BD648947651'

# %%
mentor1.set_NID(1256456)
# Out:
# Please provide a string NID

# %%
mentor1.getNIDforUN()
# Out:
# 'BD648947651'

# %%
mentor1.set_NID("1256456")

# %%
mentor1.getNIDforUN()
# Out:
# 'BD1256456'

# %% [markdown]
# __this whole concept in the above (getter and setter) are Encapsulation :---> capsule__

# %%
class Mentor:

    def __init__(self, name, number,NID):
        self.name = name
        #self.number = number
        self.__number = number # this "__" makes it private
        self.__NID = NID

    def __str__(self):
        print(self.name)
        print(self.__number)
        return ""
    def get_Mobile(self):  #getter (getting the private instance number)
        print(self.__number)
        return self.__number
    def set_Mobile(self, newNumber, password): #setter (setting the private instance number)
        if (password=="0123"):
            self.__number = newNumber
    def get_NID(self):  #getter (getting the private instance NID)
        print("*******" + self.__NID[-1])
        #return self.__NID
    def set_NID(self, newNID): #setter (setting the private instance NID)
        if(type(newNID) == str):
            self.__NID = newNID
        else:
            print("Please provide a string NID")
        
    def __getNIDforUN(self): # this method is now private
        return "BD" + self.__NID

# %%
mentor1 = Mentor("Rafi","0424164","648947651")
mentor2 = Mentor("Alexa","0424164","648947651")
mentor3 = Mentor("Siri","0424164","648947651")
mentor4 = Mentor("Cortana","0424164","648947651")

l = [mentor1,mentor2,mentor3,mentor4]

for mentor in l:
    print(mentor.name) # we can access it because it is public
# Out:
# Rafi
# Alexa
# Siri
# Cortana

# %% [markdown]
# #### Problem: how many mentors are there in Ineuron?

# %% [markdown]
# #### Problem: which company is mentor part of ? -----> Ineuron

# %%
# number_of_mentor = 0 (this is global property)
class Mentor_New:

    # this __number_of_mentor & __company are called
    # Static/ Class properties
    __number_of_mentor = 0 # now this a variable of class not the instance
    __company = "Ineuron"                   # this is a class property
    #(we made the variable private so that no one can change or access it)
    ss = "I am a static property"
    def __init__(self, name, number,NID):
        
        self.name = name
        #self.number = number
        self.__number = number # this "__" makes it private
        self.__NID = NID
        Mentor_New.__number_of_mentor = Mentor_New.__number_of_mentor +1

    def __str__(self):
        print(self.name)
        print(self.__number)
        return ""
    def get_Mobile(self):  #getter (getting the private instance number)
        print(self.__number)
        return self.__number
    def set_Mobile(self, newNumber, password): #setter (setting the private instance number)
        if (password=="0123"):
            self.__number = newNumber
    def get_NID(self):  #getter (getting the private instance NID)
        print("*******" + self.__NID[-1])
        #return self.__NID
    def set_NID(self, newNID): #setter (setting the private instance NID)
        if(type(newNID) == str):
            self.__NID = newNID
        else:
            print("Please provide a string NID")
    def getNIDforUN(self):
        return "BD" + self.__NID
    

    @staticmethod  # method decorators
    def get_Number_of_Mentor(): # it is not private for object it is static instaces of class so no self would be used in here
        print(Mentor_New.__number_of_mentor)
        return Mentor_New.__number_of_mentor

# %%
m1 = Mentor_New("Cortana","0424164","648947651")
m2 = Mentor_New("Siri","095691","76352515")

# %%
m3 = Mentor_New("Cortana","0424164","648947651")
m4 = Mentor_New("Siri","095691","76352515")

# %%
m1.ss # the objects can also access the static variables
# Out:
# 'I am a static property'

# %%
Mentor_New.ss # the Class can also access the static variables
# Out:
# 'I am a static property'

# %%
Mentor_New.get_Number_of_Mentor()
# Out:
# 4
# 4

# %%
m1.get_Number_of_Mentor()
# Out:
# 4
# 4

# %%
Mentor_New.company
# Out:
# 'Ineuron'

# %%
Mentor_New.number_of_mentor = "0" # now someone changed it to string

# %%
mentor5 = Mentor_New("Rafi","0424164","648947651") # as someone changed (number_of_mentors) into string it is thorwing error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[280], line 1
# ----> 1 mentor5 = Mentor_New("Rafi","0424164","648947651")
#
# Cell In[273], line 12, in Mentor_New.__init__(self, name, number, NID)
#      10 self.__number = number # this "__" makes it private
#      11 self.__NID = NID
# ---> 12 Mentor_New.number_of_mentor = Mentor_New.number_of_mentor +1
#
# TypeError: can only concatenate str (not "int") to str

# %%
m2.number_of_mentor # the new class is formed and the number_of_mentor reset to 0 again
# Out:
# 1

# %%
from mentor_class import Mentor_New2

# %%
m1 = Mentor_New2()

# %%
class Employee:

    # this __number_of_mentor & __company are called
    # Static/ Class properties
    __nemp = 0 

    def __init__(self, name):
        
        self.name = name
        Employee.__nemp = Employee.__nemp + 1

    @staticmethod  # we have to use it so that the object can access the static variable which are private
    def get_nemp():
        return Employee.__nemp

# %%
e1 = Employee("Rafi")

# %%
e1.nemp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[351], line 1
# ----> 1 e1.nemp
#
# AttributeError: 'Employee' object has no attribute 'nemp'

# %%
Employee.nemp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[352], line 1
# ----> 1 Employee.nemp
#
# AttributeError: type object 'Employee' has no attribute 'nemp'

# %%
Employee.get_nemp()
# Out:
# 1

# %%
e1.get_nemp()
# Out:
# 1

# %%
e2 = Employee("Alexa")

# %%
e2.get_nemp()
# Out:
# 2
