# %% [markdown]
# # Compund Assignement operator

# %%
 a=10

# %%
a+=1

# %%
a
# Out:
# 11

# %%
++a
# Out:
# 11

# %%
a
# Out:
# 11

# %%
+-a #it works as a sign multiplication in python
# Out:
# -11

# %% [markdown]
# ## in Python there is no pre or post increment like java or C#

# %% [markdown]
# # Identity Operator

# %% [markdown]
# ## 1. is
# ## 2. is not
# ## it is used to check is thhe value is of certain type

# %%
c = 5

# %%
type(c)
# Out:
# int

# %%
type(c) is int
# Out:
# True

# %%
type(c) is not int
# Out:
# False

# %%
c
# Out:
# 5

# %%
type(c) is not str
# Out:
# True

# %%
type(c) == int
# Out:
# True

# %% [markdown]
# ## This Operator is also used to verify if two references have same memmory location

# %%
a = 5
b = 6
c = 5

# %%
id(a) # we are geting  the address from the memory where it is stored
# Out:
# 140710126654376

# %%
id(c)
# Out:
# 140710126654376

# %%
id(b)
# Out:
# 140710126654408

# %%
id(a) == id (c)
# Out:
# True

# %% [markdown]
# ### so as the value of the a and c is same so the value reside in the same address in the memory

# %%
 a, str1 = 9, 'Rafi'

# %%
id(str1)
# Out:
# 1993735531632

# %%
id(a)
# Out:
# 140710126654504

# %%
a
# Out:
# 9

# %%
c=a

# %%
c
# Out:
# 9

# %%
id(c)
# Out:
# 140710126654504

# %%
a= 3

# %%
id(a)
# Out:
# 140710126654312

# %%
c
# Out:
# 9

# %%
id(c)
# Out:
# 140710126654504

# %%
str1 = 'Rafi'

# %%
str2 = 'Rafi'

# %%
str1 is str2
# Out:
# True

# %% [markdown]
# # Membership Operator

# %% [markdown]
# ### 1. in
# ### 2. not in

# %%
orders = ['Biryani', 'icecream', 'dosa']

# %%
'Biryani' in orders
# Out:
# True

# %%
'fi' in 'Rafi'
# Out:
# True

# %%
'f' in 'Rafi'
# Out:
# True

# %%
'Biryani' in orders and 'icecream' in orders
# Out:
# True

# %%
['Biryani', 'icecream'] in orders
# Out:
# False

# %%
orders = ['Biryani', 'icecream', 'dosa',['Biryani', 'icecream']]

# %%
orders
# Out:
# ['Biryani', 'icecream', 'dosa', ['Biryani', 'icecream']]

# %%
['Biryani', 'icecream'] in orders
# Out:
# True

# %%
'Biryani'and'dosa' in orders
# Out:
# True

# %%
orders = ['Biryani', 'icecream', 'dosa',['Biryani', 'icecream','dosa']]

# %%
['Biryani', 'icecream','dosa'] in orders
# Out:
# True

# %%
['Biryani','dosa','icecream'] in orders
# Out:
# False

# %%
'Biryani'or'dosa' in orders
# Out:
# 'Biryani'

# %% [markdown]
# # precedance of operator

# %%
45+50/5
# Out:
# 55.0

# %%
6/2+3**4
# Out:
# 84.0

# %% [markdown]
# # Associativity in Python

# %% [markdown]
# #### When 2 or more operators follow same precedence then Python follows associativity
# #### so the the associativity follows form left to right (almost all)

# %%
2**3**2 # exception
# Out:
# 512

# %%
2**9
# Out:
# 512
