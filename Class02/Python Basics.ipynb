# %%
print("Hello")
# Out:
# Hello

# %%
a=5
b=6

print(a+b)
# Out:
# 11

# %% [markdown]
# ## Funtion works

# %% [markdown]
# First define the funtion then use that function

# %%
def sum(a,b):
    print(a+b)

# %%
a=6
b=10

sum(a,b)
# Out:
# 16

# %%
c=10
d=1111111

sum(c,d)
# Out:
# 1111121

# %% [markdown]
# ### In built Function

# %%
print(pow(3,2))
# Out:
# 9

# %% [markdown]
# ## User defined funtion

# %%
a=23
b=54
sum(a,b)
# Out:
# 77

# %%
sum(5,54)
# Out:
# 59

# %% [markdown]
# ## print Funtion

# %%
a=5
a
# Out:
# 5

# %%
b=10
print(b)
# Out:
# 10

# %%
"hello world"
e=5
e
# Out:
# 5

# %%
a=5
c=10
print(a+c)
d=20
print(a+d)
e
# Out:
# 15
# 25
# 5

# %%
print("hello")
print("World")
# Out:
# hello
# World

# %%
print("hello Wold")
# Out:
# hello Wold

# %%
def mySumFunct(a,b=10):
    print(a+b)

# %%
mySumFunct(12)
# Out:
# 22

# %%
mySumFunct(10,3)
# Out:
# 13

# %% [markdown]
# here the 3 has overidden the default value of b=10

# %%
def mySumfunct2(a,b):
    print(a+b)

# %% [markdown]
# #### mySumfunct2(10) won't work because the b is no prevalued in this case

# %%
print("hello",end=" ")
print("World",end="<---------")
# Out:
# hello World<---------

# %% [markdown]
# here in the print function the end argument "\n" has been replaced with a space and then goes to the next line to execute

# %%
print("the mean is", end=" ")
print("5.55")
# Out:
# the mean is 5.55

# %%
print(" +9-9999999912", end='\b')
# Out:
#  +9-999999991

# %% [markdown]
# this '\b' is used to remove the last character of the string

# %%
print("hello", end='\b')
print("python")
# Out:
# hellpython

# %%
print("hello", end='\t')
print("Python")
# Out:
# hello	Python

# %% [markdown]
# this '\t' is just creating space between the two print

# %%
print("hello", end='\b\b')
# Out:
# hel

# %%
print("Hello","Word",sep='\n')
# Out:
# Hello
# Word

# %%
print("Hello","Word","Python",sep='<<<<<>>>>>>')
# Out:
# Hello<<<<<>>>>>>Word<<<<<>>>>>>Python

# %%
print("hello","World",sep=",",end="!!!!!!!!!")
# Out:
# hello,World!!!!!!!!!

# %% [markdown]
# ## input Function

# %%
input()
# Out:
#  6
# '6'

# %%
firstNumber = input()
print(firstNumber)
# Out:
#  45
# 45

# %%
first=input("Enter the 1st number")
second=input("Enter the 2nd number")
third=input("Enter the 3rd number")
# Out:
# Enter the 1st number 5
# Enter the 2nd number 6
# Enter the 3rd number 10

# %%
input()
# Out:
#  10
# '10'

# %%
print(first,second,third)
# Out:
# 5 6 10

# %%
type(first)
# Out:
# str
