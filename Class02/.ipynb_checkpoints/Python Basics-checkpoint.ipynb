# %%
print("Hello")
# Out:
# Hello

# %%
a=5
b=6

print(a+b)
# Out:
# 11

# %% [markdown]
# ## Funtion works

# %% [markdown]
# First define the funtion then use that function

# %%
def sum(a,b):
    print(a+b)

# %%
a=6
b=10

sum(a,b)
# Out:
# 16

# %%
c=10
d=1111111

sum(c,d)
# Out:
# 1111121

# %% [markdown]
# ### In built Function

# %%
print(pow(3,2))
# Out:
# 9
