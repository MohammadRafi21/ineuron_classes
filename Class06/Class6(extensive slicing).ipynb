# %%
s= 'PYTHON'

# %%
s[0:33434]
# Out:
# 'PYTHON'

# %% [markdown]
# slicing try to give you a empty set if there is any problem

# %% [markdown]
# # Slicing
# ### it will be same/ used in every sequence(tuple, list, str, array, range)

# %% [markdown]
# # step/ stride

# %%
s[0:4]
# Out:
# 'PYTH'

# %%
s[1:4:1]
# Out:
# 'YTH'

# %%
s[0:4:2]
# Out:
# 'PT'

# %%
s[0:5:2]
# Out:
# 'PTO'

# %%
s[1:4:2]
# Out:
# 'YH'

# %%
s1 = s*4

# %%
s1[0:len(s1):2]
# Out:
# 'PTOPTOPTOPTO'

# %%
l = 'IndianPremierLeague'

# %%
l[0:14:3]
# Out:
# 'IiPmr'

# %%
s[0:100:3]
# Out:
# 'PH'

# %%
s[0:6:3]
# Out:
# 'PH'

# %%
s[2:2] # default stride is 1
# Out:
# ''

# %%
s[4:4] # default stride is 1
# Out:
# ''

# %%
s[0:6:10000]
# Out:
# 'P'

# %%
s[0:6:100]
# Out:
# 'P'

# %%
s[-4:-1]
# Out:
# 'THO'

# %%
s[-1:-4] # as the default jump is 1 so it will move forward so by moving forward there is nothing so it will give an empty set
# Out:
# ''

# %%
s[-1:-4:-1] # as there us a negative jump it can move backward now
# Out:
# 'NOH'

# %%
s[-1:-4:-2]
# Out:
# 'NH'

# %%
s[0:5:-1]
# Out:
# ''

# %%
s[2:2:-1]
# Out:
# ''

# %%
s[::-1]
# Out:
# 'NOHTYP'

# %%
s[-1:-4:-1000]
# Out:
# 'N'

# %%
s[-1:-4:1000]
# Out:
# ''

# %%
s[-4:0]
# Out:
# ''

# %%
s[-1:-6:-2]
# Out:
# 'NHY'

# %% [markdown]
# ## If the direction is +ve that is +1 end becomes (end - 1)
# ## tf the direction is -ve that is -1 end becomes (end + 1)

# %%
s[2:2:-1]

#start 2
#end 3
# direction -ve
# you can never reach 3 form 2 if you move left form the start hence it is empty
# Out:
# ''

# %%
s[-1:-len(s)-1:-1]
# Out:
# 'NOHTYP'

# %%
s[-1:-len(s):-1]
# Out:
# 'NOHTY'

# %%
ex = 'Industry'

# %%
ex[2:6:2]
# Out:
# 'ds'

# %%
ex[-5:-8:1]
# Out:
# ''

# %%
ex[-7:-5:1]
# Out:
# 'nd'

# %%
ex[-8:-5:1]
# Out:
# 'Ind'

# %%
s = 'PROGRAM' 
# find the Output "RGO"

# %%
s[-3:-6:-1]
# Out:
# 'RGO'

# %%
s = 'PROGRAM' 
# find the Output "RGA"

# %%
s[1:6:2]
# Out:
# 'RGA'

# %%
s[1::2]
# Out:
# 'RGA'

# %%
s[1:5:0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 s[1:5:0]
#
# ValueError: slice step cannot be zero
