# %% [markdown]
# # Operators

# %% [markdown]
# #### Operators are special symbols
# #### They work on operands

# %% [markdown]
# # 1. Arithmetic Operators

# %% [markdown]
# ### (+,-,*,/,%,**,//) are arithmeric operator

# %%
5/2
# Out:
# 2.5

# %% [markdown]
# ### modulus

# %%
5 % 2 # basically it will give you the remainder of the division
# Out:
# 1

# %%
55 % 7
# Out:
# 6

# %%
555 % 7
# Out:
# 2

# %% [markdown]
# ### Exponential (**)

# %%
2*2*2*2*2
# Out:
# 32

# %%
2**4 # it implies 2 to the power 4
# Out:
# 16

# %% [markdown]
# ## floor division(//)

# %% [markdown]
# ##### it takes the integral part of the division

# %%
5//2 # it ignore any thing after the decimal point
# Out:
# 2

# %%
99//10
# Out:
# 9

# %% [markdown]
# ### it is not rounding of it just take the value before the decimal that's it

# %%
56//5
# Out:
# 11

# %% [markdown]
# # 2. Relational Operators

# %% [markdown]
# #### (>,<,==,>=,<=,!=) are relational operators

# %%
4==5
# Out:
# False

# %%
4!=5
# Out:
# True

# %% [markdown]
# ##### The relational operator in integer
# ##### they will give you boolean output

# %%
4>5
# Out:
# False

# %%
5<5
# Out:
# False

# %%
a = 10

# %%
a==12
# Out:
# False

# %%
a!=12
# Out:
# True

# %%
a>=5
# Out:
# True

# %%
a<=5
# Out:
# False

# %%
a<=11
# Out:
# True

# %%
a<=9
# Out:
# False

# %%
--a==9
# Out:
# False

# %% [markdown]
# ##### The relational operator in string

# %%
pay = 200

# %%
pay >= 150
# Out:
# True
